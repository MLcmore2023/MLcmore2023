# %% [markdown]
# # CME538 - Introduction to Data Science
# ## Assignment 4 - Exploratory Data Analysis
#
# **Learning Objectives**
# After completing this assignment, you should be comfortable:
#
# - Using `matplotlib` and `seaborn` for data visualization.
# - Using more advanced `Pandas` grouping and aggregating methods.
# - Resampling DateTime indices.
# - Working with datetime columns in `Pandas`.
# - Removing outliers.
# - Investigating missing data.
#
# You are free to add new cells to use as a scratch pad, but make sure to clean you code up and present your answer in the cell indicated with `# Write your code here`.
#
# **Marking Breakdown**
#
# Question | Points
# --- | ---
# Question 1a | 1
# Question 1b | 1
# Question 1c | 1
# Question 1d | 1
# Question 1e | 1
# Question 2a | 1
# Question 2b | 1
# Question 2c | 1
# Question 3a | 1
# Question 3b | 1
# Question 4a | 1
# Question 4b | 1
# Question 4c | 1
# Question 5 | 1
# Question 6 | 1
# Question 7a | 1
# Question 7b | 1
# Question 7c | 1
# Question 7d | 1
# Question 7e | 1
# Question 7f | 1
# Question 7g | 1
# Question 8a | 1
# Question 8b | 1
# Question 8c | 1
# Question 8d | 1
# Question 8e | 1
# Total | 27
#
# One of the following marks below will be added to the **Total** above.
#
# ### Code Quality
#
# | Rank | Points | Description |
# | :-- | :-- | :-- |
# | Youngling | 1 | Code is unorganized, variables names are not descriptive, redundant, memory-intensive, computationally-intensive, uncommented, error-prone, difficult to understand. |
# | Padawan | 2 | Code is organized, variables names are descriptive, satisfactory utilization of memory and computational resources, satisfactory commenting, readable. |
# | Jedi | 3 | Code is organized, easy to understand, efficient, clean, a pleasure to read. #cleancode |

# %% [markdown]
# ## Setup Notebook

# %%
# Import 3rd party libraries
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Overview
# You've just been hired by the City of Toronto. Congratulation! Toronto has been collecting data on its bike share program since 2017 and the 2019 data has just become available. The city has implemented some new initiatives to try to increase ridership numbers such as **Free Ride Wednesdays** in the month of September and the addition of new bike lanes. You manager has asked you to:
# 1. Merge the bike share data with local weather data from the TORONTO CITY CENTRE weather station.
# 2. Investigate the effect of temperature on ridership numbers.
# 3. Explore different consumer behaviours between Annual Members and Casual Memebers.
#
#
# # 1. Prepare Weather Data
# ## Question 1a
# First, let's check to see what weather files are available in the assignment directory. Weather file names have the following structure `en_climate_hourly_ON_6158355_01-2017_P1H.csv`. All weather file names contain the number `6158359`, which is the `TORONTO CITY CENTRE` weather station ID. Create a variable called `weather_filenames` and assign a list containing all weather file names to it.

# %%
# Write your code here.
weather_filenames = [file for file in os.listdir() if '6158359' in file]

# Print file names
print(weather_filenames[0:5])
# Out:
# ['en_climate_hourly_ON_6158359_07-2019_P1H.csv', 'en_climate_hourly_ON_6158359_12-2019_P1H.csv', 'en_climate_hourly_ON_6158359_01-2019_P1H.csv', 'en_climate_hourly_ON_6158359_06-2019_P1H.csv', 'en_climate_hourly_ON_6158359_11-2019_P1H.csv']

# %% [markdown]
# ## Question 1b
# `weather_filenames` contains 12 files containing monthly weather data for 2019. Create a variable `weather_data` and assign a DataFrame to it that contains the data from all 12 `.csv` files. Hint: `pd.concat()` might be helpful.
#
# Check out this [glossary](https://climate.weather.gc.ca/glossary_e.html#windChill) to get a better understanding of that the column names refer to.

# %%
# Write your code here.
df = pd.DataFrame()
for i in range(len(weather_filenames)):
    x = open(weather_filenames[i],'r')
    x_df = pd.read_csv(x)
    df = pd.concat([x_df,df],ignore_index=True)
weather_data = df

# View DataFrame
weather_data.head()
# Out:
#    Longitude (x)  Latitude (y)         Station Name  Climate ID  \
# 0          -79.4         43.63  TORONTO CITY CENTRE     6158359
# 1          -79.4         43.63  TORONTO CITY CENTRE     6158359
# 2          -79.4         43.63  TORONTO CITY CENTRE     6158359
# 3          -79.4         43.63  TORONTO CITY CENTRE     6158359
# 4          -79.4         43.63  TORONTO CITY CENTRE     6158359
#
#           Date/Time  Year  Month  Day   Time  Temp (°C)  ... Wind Spd Flag  \
# 0  2019-09-01 00:00  2019      9    1  00:00       18.1  ...           NaN
# 1  2019-09-01 01:00  2019      9    1  01:00       17.6  ...           NaN
# 2  2019-09-01 02:00  2019      9    1  02:00       17.7  ...           NaN
# 3  2019-09-01 03:00  2019      9    1  03:00       17.3  ...           NaN
# 4  2019-09-01 04:00  2019      9    1  04:00       17.0  ...           NaN
#
#    Visibility (km) Visibility Flag  Stn Press (kPa) Stn Press Flag  Hmdx  \
# 0             16.1             NaN           101.66            NaN   NaN
# 1             16.1             NaN           101.66            NaN   NaN
# 2             16.1             NaN           101.64            NaN   NaN
# 3             16.1             NaN           101.63            NaN   NaN
# 4             16.1             NaN           101.62            NaN   NaN
#
#   Hmdx Flag  Wind Chill Wind Chill Flag  Weather
# 0       NaN         NaN             NaN      NaN
# 1       NaN         NaN             NaN      NaN
# 2       NaN         NaN             NaN      NaN
# 3       NaN         NaN             NaN      NaN
# 4       NaN         NaN             NaN      NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Question 1c
# A column called `'Date/Time'` contains hourly datetime stamps in the format `YYYY-MM-DD HH:MM`. Use `pd.DatetimeIndex()` to set the `'Date/Time'` column as the index of `weather_data`. Now the index of `weather_data` is composed of `Timestamps`. Hint: 'weather_data.columns' should no longer contain `'Date/Time'`.

# %%
# Write your code here.
weather_data['Date/Time'] = pd.DatetimeIndex(weather_data['Date/Time'])
weather_data = weather_data.set_index('Date/Time')

# View DataFrame
weather_data.head()
# Out:
#                      Longitude (x)  Latitude (y)         Station Name  \
# Date/Time
# 2019-09-01 00:00:00          -79.4         43.63  TORONTO CITY CENTRE
# 2019-09-01 01:00:00          -79.4         43.63  TORONTO CITY CENTRE
# 2019-09-01 02:00:00          -79.4         43.63  TORONTO CITY CENTRE
# 2019-09-01 03:00:00          -79.4         43.63  TORONTO CITY CENTRE
# 2019-09-01 04:00:00          -79.4         43.63  TORONTO CITY CENTRE
#
#                      Climate ID  Year  Month  Day   Time  Temp (°C) Temp Flag  \
# Date/Time
# 2019-09-01 00:00:00     6158359  2019      9    1  00:00       18.1       NaN
# 2019-09-01 01:00:00     6158359  2019      9    1  01:00       17.6       NaN
# 2019-09-01 02:00:00     6158359  2019      9    1  02:00       17.7       NaN
# 2019-09-01 03:00:00     6158359  2019      9    1  03:00       17.3       NaN
# 2019-09-01 04:00:00     6158359  2019      9    1  04:00       17.0       NaN
#
#                      ...  Wind Spd Flag Visibility (km)  Visibility Flag  \
# Date/Time            ...
# 2019-09-01 00:00:00  ...            NaN            16.1              NaN
# 2019-09-01 01:00:00  ...            NaN            16.1              NaN
# 2019-09-01 02:00:00  ...            NaN            16.1              NaN
# 2019-09-01 03:00:00  ...            NaN            16.1              NaN
# 2019-09-01 04:00:00  ...            NaN            16.1              NaN
#
#                     Stn Press (kPa)  Stn Press Flag Hmdx  Hmdx Flag  \
# Date/Time
# 2019-09-01 00:00:00          101.66             NaN  NaN        NaN
# 2019-09-01 01:00:00          101.66             NaN  NaN        NaN
# 2019-09-01 02:00:00          101.64             NaN  NaN        NaN
# 2019-09-01 03:00:00          101.63             NaN  NaN        NaN
# 2019-09-01 04:00:00          101.62             NaN  NaN        NaN
#
#                     Wind Chill  Wind Chill Flag Weather
# Date/Time
# 2019-09-01 00:00:00        NaN              NaN     NaN
# 2019-09-01 01:00:00        NaN              NaN     NaN
# 2019-09-01 02:00:00        NaN              NaN     NaN
# 2019-09-01 03:00:00        NaN              NaN     NaN
# 2019-09-01 04:00:00        NaN              NaN     NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Question 1d
# The index of `weather_data` (`weather_data.index`) should be a series of Timestamps (e.g. `Timestamp('2019-01-01 00:00:00')`).
#
# Are these Timestamps localized to a time zone? If so, which one?

# %%
weather_data.index
# Out:
# DatetimeIndex(['2019-09-01 00:00:00', '2019-09-01 01:00:00',
#                '2019-09-01 02:00:00', '2019-09-01 03:00:00',
#                '2019-09-01 04:00:00', '2019-09-01 05:00:00',
#                '2019-09-01 06:00:00', '2019-09-01 07:00:00',
#                '2019-09-01 08:00:00', '2019-09-01 09:00:00',
#                ...
#                '2019-07-31 14:00:00', '2019-07-31 15:00:00',
#                '2019-07-31 16:00:00', '2019-07-31 17:00:00',
#                '2019-07-31 18:00:00', '2019-07-31 19:00:00',
#                '2019-07-31 20:00:00', '2019-07-31 21:00:00',
#                '2019-07-31 22:00:00', '2019-07-31 23:00:00'],
#               dtype='datetime64[ns]', name='Date/Time', length=8760, freq=None)

# %% [markdown]
# These Timestamps are not localized to a Time-Zone, as we can see from the above 'dtype'.

# %% [markdown]
# If the Timestamps are not localized, localize them to Toronto's time zone (Eastern Standard Time - `EST`).

# %%
# Write your code here.
weather_data.index = weather_data.index.tz_localize('EST')
weather_data.index
# Out:
# DatetimeIndex(['2019-09-01 00:00:00-05:00', '2019-09-01 01:00:00-05:00',
#                '2019-09-01 02:00:00-05:00', '2019-09-01 03:00:00-05:00',
#                '2019-09-01 04:00:00-05:00', '2019-09-01 05:00:00-05:00',
#                '2019-09-01 06:00:00-05:00', '2019-09-01 07:00:00-05:00',
#                '2019-09-01 08:00:00-05:00', '2019-09-01 09:00:00-05:00',
#                ...
#                '2019-07-31 14:00:00-05:00', '2019-07-31 15:00:00-05:00',
#                '2019-07-31 16:00:00-05:00', '2019-07-31 17:00:00-05:00',
#                '2019-07-31 18:00:00-05:00', '2019-07-31 19:00:00-05:00',
#                '2019-07-31 20:00:00-05:00', '2019-07-31 21:00:00-05:00',
#                '2019-07-31 22:00:00-05:00', '2019-07-31 23:00:00-05:00'],
#               dtype='datetime64[ns, EST]', name='Date/Time', length=8760, freq=None)

# %% [markdown]
# These Timestamps are now localized to a EST, as we can see from the above 'dtype'.

# %%
# View DataFrame
weather_data.head()
# Out:
#                            Longitude (x)  Latitude (y)         Station Name  \
# Date/Time
# 2019-09-01 00:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
# 2019-09-01 01:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
# 2019-09-01 02:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
# 2019-09-01 03:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
# 2019-09-01 04:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
#
#                            Climate ID  Year  Month  Day   Time  Temp (°C)  \
# Date/Time
# 2019-09-01 00:00:00-05:00     6158359  2019      9    1  00:00       18.1
# 2019-09-01 01:00:00-05:00     6158359  2019      9    1  01:00       17.6
# 2019-09-01 02:00:00-05:00     6158359  2019      9    1  02:00       17.7
# 2019-09-01 03:00:00-05:00     6158359  2019      9    1  03:00       17.3
# 2019-09-01 04:00:00-05:00     6158359  2019      9    1  04:00       17.0
#
#                           Temp Flag  ...  Wind Spd Flag Visibility (km)  \
# Date/Time                            ...
# 2019-09-01 00:00:00-05:00       NaN  ...            NaN            16.1
# 2019-09-01 01:00:00-05:00       NaN  ...            NaN            16.1
# 2019-09-01 02:00:00-05:00       NaN  ...            NaN            16.1
# 2019-09-01 03:00:00-05:00       NaN  ...            NaN            16.1
# 2019-09-01 04:00:00-05:00       NaN  ...            NaN            16.1
#
#                            Visibility Flag Stn Press (kPa)  Stn Press Flag  \
# Date/Time
# 2019-09-01 00:00:00-05:00              NaN          101.66             NaN
# 2019-09-01 01:00:00-05:00              NaN          101.66             NaN
# 2019-09-01 02:00:00-05:00              NaN          101.64             NaN
# 2019-09-01 03:00:00-05:00              NaN          101.63             NaN
# 2019-09-01 04:00:00-05:00              NaN          101.62             NaN
#
#                           Hmdx  Hmdx Flag Wind Chill  Wind Chill Flag Weather
# Date/Time
# 2019-09-01 00:00:00-05:00  NaN        NaN        NaN              NaN     NaN
# 2019-09-01 01:00:00-05:00  NaN        NaN        NaN              NaN     NaN
# 2019-09-01 02:00:00-05:00  NaN        NaN        NaN              NaN     NaN
# 2019-09-01 03:00:00-05:00  NaN        NaN        NaN              NaN     NaN
# 2019-09-01 04:00:00-05:00  NaN        NaN        NaN              NaN     NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Question 1e
# Next, plot temperature as a function of the datetime index. Your plot should look something like this.
#
# <br>
# <img src="images/temp_2019.png" alt="drawing" width="600"/>
# <br>

# %%
# Write your code here.
plt.figure(figsize=(10,5))
plt.title('Temperature in the Toronto City Centre for 2019',fontsize=15)
df=weather_data
graph = sns.lineplot(x= df.index, y = df.iloc[:,8])
graph.xaxis.set_tick_params(labelsize=10)
graph.yaxis.set_tick_params(labelsize=10)
graph.set_xlabel('Date-Time', fontsize=15)
graph.set_ylabel('Temperature, °C', fontsize=15)
plt.show()

# %% [markdown]
# # 2. Import Bike Share Data
# The assignment folder contains data about bike share trips in the city of Toronto for 2019 where there is one `.csv` file for each month. File names have the structure `bike_share_YYYY-MM.csv`.

# %%
# Get bike share file names
trips_filenames = [filename for filename in os.listdir() if 'bike_share' in filename]

# Print file names
print(trips_filenames[0:5])
# Out:
# ['bike_share_2019-1.csv', 'bike_share_2019-2.csv', 'bike_share_2019-3.csv', 'bike_share_2019-7.csv', 'bike_share_2019-6.csv']

# %% [markdown]
# ## Question 2a
# Create a variable `trips_data` and assign a DataFrame to it that contains the bike share data from all 12 `.csv` files.

# %%
# Write your code here.
df = pd.DataFrame()
for i in range(len(trips_filenames)):
    x = open(trips_filenames[i],'r')
    x_df = pd.read_csv(x)
    df = pd.concat([x_df,df], ignore_index=True)
trips_data = df

# Let's remove double spaces from the column names
trips_data.columns = [' '.join(col.split()) for col in trips_data.columns]              

# View DataFrame
trips_data.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0  6426456           471215            711              7207
# 1  6426455           463175            517              7462
# 2  6426453           468059            460              7210
# 3  6426452           468816            229              7251
# 4  6426454           471340            612              7467
#
#             Start Time                            Start Station Name  \
# 0  2019-09-01 00:00:00                     Dundas St W / Crawford St
# 1  2019-09-01 00:00:00                      Richmond St E / Yonge St
# 2  2019-09-01 00:00:00      Mary McCormick Rec Centre (Sheridan Ave)
# 3  2019-09-01 00:00:00  The Royal Ontario Museum (Bloor St Entrance)
# 4  2019-09-01 00:00:00                Lower Simcoe St / Bremner Blvd
#
#    End Station Id             End Time  \
# 0          7150.0  2019-09-01 00:12:00
# 1          7385.0  2019-09-01 00:08:00
# 2          7136.0  2019-09-01 00:07:00
# 3          7419.0  2019-09-01 00:03:00
# 4          7016.0  2019-09-01 00:10:00
#
#                                 End Station Name  Bike Id      User Type
# 0  Dufferin St / Sylvan Av (Dufferin Grove Park)     3331  Casual Member
# 1                                20 Charles St E     1534  Annual Member
# 2                         Queen St W / Close Ave      877  Casual Member
# 3                          Bloor St W / Huron St      640  Casual Member
# 4        Bay St / Queens Quay W (Ferry Terminal)     2722  Casual Member

# %%
trips_data.shape
# Out:
# (2439517, 11)

# %% [markdown]
# ## Question 2b
# Next, convert columns `'Start Time'` and `'End Time'` to datetimes. Then, localize `'Start Time'` and `'End Time'` to Eastern Standard Time (EST). This might take a minute or two.

# %%
# Write your code here.
trips_data['Start Time'] = pd.DatetimeIndex(trips_data['Start Time']).tz_localize('EST')
trips_data['End Time'] = pd.DatetimeIndex(trips_data['End Time']).tz_localize('EST')

# View DataFrame
trips_data.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0  6426456           471215            711              7207
# 1  6426455           463175            517              7462
# 2  6426453           468059            460              7210
# 3  6426452           468816            229              7251
# 4  6426454           471340            612              7467
#
#                  Start Time                            Start Station Name  \
# 0 2019-09-01 00:00:00-05:00                     Dundas St W / Crawford St
# 1 2019-09-01 00:00:00-05:00                      Richmond St E / Yonge St
# 2 2019-09-01 00:00:00-05:00      Mary McCormick Rec Centre (Sheridan Ave)
# 3 2019-09-01 00:00:00-05:00  The Royal Ontario Museum (Bloor St Entrance)
# 4 2019-09-01 00:00:00-05:00                Lower Simcoe St / Bremner Blvd
#
#    End Station Id                  End Time  \
# 0          7150.0 2019-09-01 00:12:00-05:00
# 1          7385.0 2019-09-01 00:08:00-05:00
# 2          7136.0 2019-09-01 00:07:00-05:00
# 3          7419.0 2019-09-01 00:03:00-05:00
# 4          7016.0 2019-09-01 00:10:00-05:00
#
#                                 End Station Name  Bike Id      User Type
# 0  Dufferin St / Sylvan Av (Dufferin Grove Park)     3331  Casual Member
# 1                                20 Charles St E     1534  Annual Member
# 2                         Queen St W / Close Ave      877  Casual Member
# 3                          Bloor St W / Huron St      640  Casual Member
# 4        Bay St / Queens Quay W (Ferry Terminal)     2722  Casual Member

# %% [markdown]
# ## Question 2c
# To check that these datetime conversion were done correctly, generate a plot of daily ride counts. Your plot should look something like this. Hint: Check out `.resample()` and consider making a new variable.
#
# <br>
# <img src="images/trips_2019.png" alt="drawing" width="600"/>
# <br>

# %%
df_for_graph = trips_data.set_index('Start Time')
df_for_graph = df_for_graph.resample('D').count()

# %%
# Write your code here.
plt.figure(figsize=(10,5))
plt.title('Daily Bike Share Rides in the City of Toronto for 2019',fontsize=15)
df=df_for_graph
graph = sns.lineplot(x= df.index, y = df['Bike Id'])
graph.xaxis.set_tick_params(labelsize=10)
graph.yaxis.set_tick_params(labelsize=10)
graph.set_xlabel('Date-Time', fontsize=15)
graph.set_ylabel('Daily Rides', fontsize=15)
plt.show()

# %% [markdown]
# # 3. Clean Bike Share Data
# ## Question 3a - Missing Data
# Large datasets are rarely completely full (no missing values) and its always a good ideas to evaluatate if there is missing data and for what fields.
#
# First, check for missing values in `weather_data`. Create a DataFrame named `weather_data_missing` where the index in the column names of `weather_data` and there is one column named `'count'` which contains the number of missing values for a particular column.

# %%
# Write your code here.
df_1 = pd.DataFrame(weather_data.isnull().sum(axis=0))
df_2 = weather_data
df_1.rename(columns = {0:'Count'},inplace=True)
df_3 = df_2.append(df_1.transpose())
weather_data_missing = df_3.transpose()

# View DataFrame
weather_data_missing
# Out:
#                     2019-09-01 00:00:00-05:00 2019-09-01 01:00:00-05:00  \
# Longitude (x)                           -79.4                     -79.4
# Latitude (y)                            43.63                     43.63
# Station Name              TORONTO CITY CENTRE       TORONTO CITY CENTRE
# Climate ID                            6158359                   6158359
# Year                                     2019                      2019
# Month                                       9                         9
# Day                                         1                         1
# Time                                    00:00                     01:00
# Temp (°C)                                18.1                      17.6
# Temp Flag                                 NaN                       NaN
# Dew Point Temp (°C)                      12.0                      11.4
# Dew Point Temp Flag                       NaN                       NaN
# Rel Hum (%)                              67.0                      67.0
# Rel Hum Flag                              NaN                       NaN
# Wind Dir (10s deg)                        8.0                       6.0
# Wind Dir Flag                             NaN                       NaN
# Wind Spd (km/h)                           8.0                       9.0
# Wind Spd Flag                             NaN                       NaN
# Visibility (km)                          16.1                      16.1
# Visibility Flag                           NaN                       NaN
# Stn Press (kPa)                        101.66                    101.66
# Stn Press Flag                            NaN                       NaN
# Hmdx                                      NaN                       NaN
# Hmdx Flag                                 NaN                       NaN
# Wind Chill                                NaN                       NaN
# Wind Chill Flag                           NaN                       NaN
# Weather                                   NaN                       NaN
#
#                     2019-09-01 02:00:00-05:00 2019-09-01 03:00:00-05:00  \
# Longitude (x)                           -79.4                     -79.4
# Latitude (y)                            43.63                     43.63
# Station Name              TORONTO CITY CENTRE       TORONTO CITY CENTRE
# Climate ID                            6158359                   6158359
# Year                                     2019                      2019
# Month                                       9                         9
# Day                                         1                         1
# Time                                    02:00                     03:00
# Temp (°C)                                17.7                      17.3
# Temp Flag                                 NaN                       NaN
# Dew Point Temp (°C)                      11.0                      10.2
# Dew Point Temp Flag                       NaN                       NaN
# Rel Hum (%)                              64.0                      63.0
# Rel Hum Flag                              NaN                       NaN
# Wind Dir (10s deg)                        7.0                       6.0
# Wind Dir Flag                             NaN                       NaN
# Wind Spd (km/h)                          13.0                      13.0
# Wind Spd Flag                             NaN                       NaN
# Visibility (km)                          16.1                      16.1
# Visibility Flag                           NaN                       NaN
# Stn Press (kPa)                        101.64                    101.63
# Stn Press Flag                            NaN                       NaN
# Hmdx                                      NaN                       NaN
# Hmdx Flag                                 NaN                       NaN
# Wind Chill                                NaN                       NaN
# Wind Chill Flag                           NaN                       NaN
# Weather                                   NaN                       NaN
#
#                     2019-09-01 04:00:00-05:00 2019-09-01 05:00:00-05:00  \
# Longitude (x)                           -79.4                     -79.4
# Latitude (y)                            43.63                     43.63
# Station Name              TORONTO CITY CENTRE       TORONTO CITY CENTRE
# Climate ID                            6158359                   6158359
# Year                                     2019                      2019
# Month                                       9                         9
# Day                                         1                         1
# Time                                    04:00                     05:00
# Temp (°C)                                17.0                      16.9
# Temp Flag                                 NaN                       NaN
# Dew Point Temp (°C)                      10.9                      10.8
# Dew Point Temp Flag                       NaN                       NaN
# Rel Hum (%)                              67.0                      67.0
# Rel Hum Flag                              NaN                       NaN
# Wind Dir (10s deg)                        7.0                       6.0
# Wind Dir Flag                             NaN                       NaN
# Wind Spd (km/h)                          11.0                      15.0
# Wind Spd Flag                             NaN                       NaN
# Visibility (km)                          16.1                      16.1
# Visibility Flag                           NaN                       NaN
# Stn Press (kPa)                        101.62                    101.56
# Stn Press Flag                            NaN                       NaN
# Hmdx                                      NaN                       NaN
# Hmdx Flag                                 NaN                       NaN
# Wind Chill                                NaN                       NaN
# Wind Chill Flag                           NaN                       NaN
# Weather                                   NaN                       NaN
#
#                     2019-09-01 06:00:00-05:00 2019-09-01 07:00:00-05:00  \
# Longitude (x)                           -79.4                     -79.4
# Latitude (y)                            43.63                     43.63
# Station Name              TORONTO CITY CENTRE       TORONTO CITY CENTRE
# Climate ID                            6158359                   6158359
# Year                                     2019                      2019
# Month                                       9                         9
# Day                                         1                         1
# Time                                    06:00                     07:00
# Temp (°C)                                17.2                      17.0
# Temp Flag                                 NaN                       NaN
# Dew Point Temp (°C)                      11.6                      13.6
# Dew Point Temp Flag                       NaN                       NaN
# Rel Hum (%)                              69.0                      80.0
# Rel Hum Flag                              NaN                       NaN
# Wind Dir (10s deg)                        3.0                       6.0
# Wind Dir Flag                             NaN                       NaN
# Wind Spd (km/h)                          15.0                      22.0
# Wind Spd Flag                             NaN                       NaN
# Visibility (km)                          16.1                      16.1
# Visibility Flag                           NaN                       NaN
# Stn Press (kPa)                        101.58                    101.52
# Stn Press Flag                            NaN                       NaN
# Hmdx                                      NaN                       NaN
# Hmdx Flag                                 NaN                       NaN
# Wind Chill                                NaN                       NaN
# Wind Chill Flag                           NaN                       NaN
# Weather                                   NaN                       NaN
#
#                     2019-09-01 08:00:00-05:00 2019-09-01 09:00:00-05:00  ...  \
# Longitude (x)                           -79.4                     -79.4  ...
# Latitude (y)                            43.63                     43.63  ...
# Station Name              TORONTO CITY CENTRE       TORONTO CITY CENTRE  ...
# Climate ID                            6158359                   6158359  ...
# Year                                     2019                      2019  ...
# Month                                       9                         9  ...
# Day                                         1                         1  ...
# Time                                    08:00                     09:00  ...
# Temp (°C)                                17.9                      19.3  ...
# Temp Flag                                 NaN                       NaN  ...
# Dew Point Temp (°C)                      15.1                      15.7  ...
# Dew Point Temp Flag                       NaN                       NaN  ...
# Rel Hum (%)                              83.0                      79.0  ...
# Rel Hum Flag                              NaN                       NaN  ...
# Wind Dir (10s deg)                        5.0                       6.0  ...
# Wind Dir Flag                             NaN                       NaN  ...
# Wind Spd (km/h)                          22.0                      21.0  ...
# Wind Spd Flag                             NaN                       NaN  ...
# Visibility (km)                          16.1                      16.1  ...
# Visibility Flag                           NaN                       NaN  ...
# Stn Press (kPa)                        101.51                    101.48  ...
# Stn Press Flag                            NaN                       NaN  ...
# Hmdx                                      NaN                       NaN  ...
# Hmdx Flag                                 NaN                       NaN  ...
# Wind Chill                                NaN                       NaN  ...
# Wind Chill Flag                           NaN                       NaN  ...
# Weather                                   NaN                       NaN  ...
#
#                     2019-07-31 15:00:00-05:00 2019-07-31 16:00:00-05:00  \
# Longitude (x)                           -79.4                     -79.4
# Latitude (y)                            43.63                     43.63
# Station Name              TORONTO CITY CENTRE       TORONTO CITY CENTRE
# Climate ID                            6158359                   6158359
# Year                                     2019                      2019
# Month                                       7                         7
# Day                                        31                        31
# Time                                    15:00                     16:00
# Temp (°C)                                22.0                      23.4
# Temp Flag                                 NaN                       NaN
# Dew Point Temp (°C)                      16.4                      15.8
# Dew Point Temp Flag                       NaN                       NaN
# Rel Hum (%)                              70.0                      62.0
# Rel Hum Flag                              NaN                       NaN
# Wind Dir (10s deg)                       17.0                      19.0
# Wind Dir Flag                             NaN                       NaN
# Wind Spd (km/h)                          15.0                      11.0
# Wind Spd Flag                             NaN                       NaN
# Visibility (km)                          16.1                      16.1
# Visibility Flag                           NaN                       NaN
# Stn Press (kPa)                         100.9                    100.85
# Stn Press Flag                            NaN                       NaN
# Hmdx                                     27.0                      28.0
# Hmdx Flag                                 NaN                       NaN
# Wind Chill                                NaN                       NaN
# Wind Chill Flag                           NaN                       NaN
# Weather                                   NaN                       NaN
#
#                     2019-07-31 17:00:00-05:00 2019-07-31 18:00:00-05:00  \
# Longitude (x)                           -79.4                     -79.4
# Latitude (y)                            43.63                     43.63
# Station Name              TORONTO CITY CENTRE       TORONTO CITY CENTRE
# Climate ID                            6158359                   6158359
# Year                                     2019                      2019
# Month                                       7                         7
# Day                                        31                        31
# Time                                    17:00                     18:00
# Temp (°C)                                23.8                      21.8
# Temp Flag                                 NaN                       NaN
# Dew Point Temp (°C)                      15.3                      17.3
# Dew Point Temp Flag                       NaN                       NaN
# Rel Hum (%)                              58.0                      75.0
# Rel Hum Flag                              NaN                       NaN
# Wind Dir (10s deg)                       17.0                      23.0
# Wind Dir Flag                             NaN                       NaN
# Wind Spd (km/h)                           5.0                       4.0
# Wind Spd Flag                             NaN                       NaN
# Visibility (km)                          11.3                      16.1
# Visibility Flag                           NaN                       NaN
# Stn Press (kPa)                        100.84                    100.86
# Stn Press Flag                            NaN                       NaN
# Hmdx                                     28.0                      27.0
# Hmdx Flag                                 NaN                       NaN
# Wind Chill                                NaN                       NaN
# Wind Chill Flag                           NaN                       NaN
# Weather                                   NaN                       NaN
#
#                     2019-07-31 19:00:00-05:00 2019-07-31 20:00:00-05:00  \
# Longitude (x)                           -79.4                     -79.4
# Latitude (y)                            43.63                     43.63
# Station Name              TORONTO CITY CENTRE       TORONTO CITY CENTRE
# Climate ID                            6158359                   6158359
# Year                                     2019                      2019
# Month                                       7                         7
# Day                                        31                        31
# Time                                    19:00                     20:00
# Temp (°C)                                22.5                      24.0
# Temp Flag                                 NaN                       NaN
# Dew Point Temp (°C)                      15.5                      12.6
# Dew Point Temp Flag                       NaN                       NaN
# Rel Hum (%)                              64.0                      48.0
# Rel Hum Flag                              NaN                       NaN
# Wind Dir (10s deg)                       21.0                      35.0
# Wind Dir Flag                             NaN                       NaN
# Wind Spd (km/h)                           5.0                      13.0
# Wind Spd Flag                             NaN                       NaN
# Visibility (km)                          16.1                      16.1
# Visibility Flag                           NaN                       NaN
# Stn Press (kPa)                        100.87                    100.92
# Stn Press Flag                            NaN                       NaN
# Hmdx                                     27.0                      27.0
# Hmdx Flag                                 NaN                       NaN
# Wind Chill                                NaN                       NaN
# Wind Chill Flag                           NaN                       NaN
# Weather                                   NaN                       NaN
#
#                     2019-07-31 21:00:00-05:00 2019-07-31 22:00:00-05:00  \
# Longitude (x)                           -79.4                     -79.4
# Latitude (y)                            43.63                     43.63
# Station Name              TORONTO CITY CENTRE       TORONTO CITY CENTRE
# Climate ID                            6158359                   6158359
# Year                                     2019                      2019
# Month                                       7                         7
# Day                                        31                        31
# Time                                    21:00                     22:00
# Temp (°C)                                22.6                      21.1
# Temp Flag                                 NaN                       NaN
# Dew Point Temp (°C)                      12.9                      12.7
# Dew Point Temp Flag                       NaN                       NaN
# Rel Hum (%)                              54.0                      58.0
# Rel Hum Flag                              NaN                       NaN
# Wind Dir (10s deg)                       35.0                      34.0
# Wind Dir Flag                             NaN                       NaN
# Wind Spd (km/h)                          15.0                      21.0
# Wind Spd Flag                             NaN                       NaN
# Visibility (km)                          16.1                      16.1
# Visibility Flag                           NaN                       NaN
# Stn Press (kPa)                        100.99                    101.01
# Stn Press Flag                            NaN                       NaN
# Hmdx                                     25.0                       NaN
# Hmdx Flag                                 NaN                       NaN
# Wind Chill                                NaN                       NaN
# Wind Chill Flag                           NaN                       NaN
# Weather                                   NaN                       NaN
#
#                     2019-07-31 23:00:00-05:00   Count
# Longitude (x)                           -79.4     0.0
# Latitude (y)                            43.63     0.0
# Station Name              TORONTO CITY CENTRE       0
# Climate ID                            6158359       0
# Year                                     2019       0
# Month                                       7       0
# Day                                        31       0
# Time                                    23:00       0
# Temp (°C)                                20.5    95.0
# Temp Flag                                 NaN    8681
# Dew Point Temp (°C)                      12.8   145.0
# Dew Point Temp Flag                       NaN    8631
# Rel Hum (%)                              61.0   145.0
# Rel Hum Flag                              NaN    8631
# Wind Dir (10s deg)                       35.0   595.0
# Wind Dir Flag                             NaN    8450
# Wind Spd (km/h)                          13.0    23.0
# Wind Spd Flag                             NaN    8753
# Visibility (km)                          16.1    24.0
# Visibility Flag                           NaN    8752
# Stn Press (kPa)                        101.01    97.0
# Stn Press Flag                            NaN    8679
# Hmdx                                      NaN  7608.0
# Hmdx Flag                                 NaN  8760.0
# Wind Chill                                NaN  6936.0
# Wind Chill Flag                           NaN  8760.0
# Weather                                   NaN    7213
#
# [27 rows x 8761 columns]

# %% [markdown]
# Next, check for missing values in `trips_data`. Create a DataFrame named `trips_data_missing` where the index in the column names of `trips_data` and there is one column named `'count'` which contains the number of missing values for a particular column.

# %%
# Write your code here.
df_1 = pd.DataFrame(trips_data.isnull().sum(axis=0))
df_2 = trips_data
df_1.rename(columns = {0:'Count'},inplace=True)
df_3 = df_2.append(df_1.transpose())
trips_data_missing = df_3.transpose()

# View DataFrame
trips_data_missing
# Out:
#                                                                 0  \
# Trip Id                                                   6426456
# Subscription Id                                            471215
# Trip Duration                                                 711
# Start Station Id                                             7207
# Start Time                              2019-09-01 00:00:00-05:00
# Start Station Name                      Dundas St W / Crawford St
# End Station Id                                             7150.0
# End Time                                2019-09-01 00:12:00-05:00
# End Station Name    Dufferin St / Sylvan Av (Dufferin Grove Park)
# Bike Id                                                      3331
# User Type                                           Casual Member
#
#                                             1  \
# Trip Id                               6426455
# Subscription Id                        463175
# Trip Duration                             517
# Start Station Id                         7462
# Start Time          2019-09-01 00:00:00-05:00
# Start Station Name   Richmond St E / Yonge St
# End Station Id                         7385.0
# End Time            2019-09-01 00:08:00-05:00
# End Station Name              20 Charles St E
# Bike Id                                  1534
# User Type                       Annual Member
#
#                                                            2  \
# Trip Id                                              6426453
# Subscription Id                                       468059
# Trip Duration                                            460
# Start Station Id                                        7210
# Start Time                         2019-09-01 00:00:00-05:00
# Start Station Name  Mary McCormick Rec Centre (Sheridan Ave)
# End Station Id                                        7136.0
# End Time                           2019-09-01 00:07:00-05:00
# End Station Name                      Queen St W / Close Ave
# Bike Id                                                  877
# User Type                                      Casual Member
#
#                                                                3  \
# Trip Id                                                  6426452
# Subscription Id                                           468816
# Trip Duration                                                229
# Start Station Id                                            7251
# Start Time                             2019-09-01 00:00:00-05:00
# Start Station Name  The Royal Ontario Museum (Bloor St Entrance)
# End Station Id                                            7419.0
# End Time                               2019-09-01 00:03:00-05:00
# End Station Name                           Bloor St W / Huron St
# Bike Id                                                      640
# User Type                                          Casual Member
#
#                                                           4  \
# Trip Id                                             6426454
# Subscription Id                                      471340
# Trip Duration                                           612
# Start Station Id                                       7467
# Start Time                        2019-09-01 00:00:00-05:00
# Start Station Name           Lower Simcoe St / Bremner Blvd
# End Station Id                                       7016.0
# End Time                          2019-09-01 00:10:00-05:00
# End Station Name    Bay St / Queens Quay W (Ferry Terminal)
# Bike Id                                                2722
# User Type                                     Casual Member
#
#                                                                 5  \
# Trip Id                                                   6426458
# Subscription Id                                            471221
# Trip Duration                                                 659
# Start Station Id                                             7207
# Start Time                              2019-09-01 00:01:00-05:00
# Start Station Name                      Dundas St W / Crawford St
# End Station Id                                             7150.0
# End Time                                2019-09-01 00:12:00-05:00
# End Station Name    Dufferin St / Sylvan Av (Dufferin Grove Park)
# Bike Id                                                      2218
# User Type                                           Casual Member
#
#                                             6  \
# Trip Id                               6426459
# Subscription Id                        301506
# Trip Duration                            1115
# Start Station Id                         7033
# Start Time          2019-09-01 00:01:00-05:00
# Start Station Name              Union Station
# End Station Id                         7055.0
# End Time            2019-09-01 00:20:00-05:00
# End Station Name       Jarvis St / Carlton St
# Bike Id                                  3152
# User Type                       Annual Member
#
#                                                             7  \
# Trip Id                                               6426460
# Subscription Id                                        471342
# Trip Duration                                            1198
# Start Station Id                                         7068
# Start Time                          2019-09-01 00:01:00-05:00
# Start Station Name  Dockside Dr / Queens Quay E (Sugar Beach)
# End Station Id                                         7168.0
# End Time                            2019-09-01 00:21:00-05:00
# End Station Name                       Queens Quay / Yonge St
# Bike Id                                                  4604
# User Type                                       Casual Member
#
#                                                                 8  \
# Trip Id                                                   6426461
# Subscription Id                                            471217
# Trip Duration                                                 600
# Start Station Id                                             7207
# Start Time                              2019-09-01 00:01:00-05:00
# Start Station Name                      Dundas St W / Crawford St
# End Station Id                                             7150.0
# End Time                                2019-09-01 00:11:00-05:00
# End Station Name    Dufferin St / Sylvan Av (Dufferin Grove Park)
# Bike Id                                                      3920
# User Type                                           Casual Member
#
#                                             9  ...  \
# Trip Id                               6426462  ...
# Subscription Id                        470966  ...
# Trip Duration                            1246  ...
# Start Station Id                         7378  ...
# Start Time          2019-09-01 00:01:00-05:00  ...
# Start Station Name  Yonge St / Davisville Ave  ...
# End Station Id                         7126.0  ...
# End Time            2019-09-01 00:22:00-05:00  ...
# End Station Name     Yonge St / Yorkville Ave  ...
# Bike Id                                   753  ...
# User Type                       Casual Member  ...
#
#                                                2439508  \
# Trip Id                                        4653110
# Subscription Id                                 223770
# Trip Duration                                      983
# Start Station Id                                  7062
# Start Time                   2019-01-31 22:24:00-05:00
# Start Station Name  University Ave / College St (West)
# End Station Id                                  7100.0
# End Time                     2019-01-31 22:40:00-05:00
# End Station Name        Dundas St E / Regent Park Blvd
# Bike Id                                            631
# User Type                                Annual Member
#
#                                            2439509  \
# Trip Id                                    4653111
# Subscription Id                             248366
# Trip Duration                                  857
# Start Station Id                              7252
# Start Time               2019-01-31 22:27:00-05:00
# Start Station Name  Robert St / Bloor St W - SMART
# End Station Id                              7069.0
# End Time                 2019-01-31 22:42:00-05:00
# End Station Name          Queen St W / Spadina Ave
# Bike Id                                       2430
# User Type                            Annual Member
#
#                                            2439510  \
# Trip Id                                    4653112
# Subscription Id                             286799
# Trip Duration                                  351
# Start Station Id                              7282
# Start Time               2019-01-31 22:30:00-05:00
# Start Station Name  Adelaide St W / Bay St - SMART
# End Station Id                              7060.0
# End Time                 2019-01-31 22:36:00-05:00
# End Station Name       Princess St / Adelaide St E
# Bike Id                                        358
# User Type                            Annual Member
#
#                                         2439511  \
# Trip Id                                 4653113
# Subscription Id                          254361
# Trip Duration                               450
# Start Station Id                           7038
# Start Time            2019-01-31 22:35:00-05:00
# Start Station Name       Dundas St W / Yonge St
# End Station Id                           7065.0
# End Time              2019-01-31 22:43:00-05:00
# End Station Name    Dundas St E / Parliament St
# Bike Id                                    3292
# User Type                         Annual Member
#
#                                                          2439512  \
# Trip Id                                                  4653114
# Subscription Id                                           223690
# Trip Duration                                                420
# Start Station Id                                            7251
# Start Time                             2019-01-31 22:55:00-05:00
# Start Station Name  The Royal Ontario Museum (Bloor St Entrance)
# End Station Id                                            7026.0
# End Time                               2019-01-31 23:02:00-05:00
# End Station Name                          Bay St / St. Joseph St
# Bike Id                                                     3303
# User Type                                          Annual Member
#
#                                             2439513  \
# Trip Id                                     4653115
# Subscription Id                              310973
# Trip Duration                                   589
# Start Station Id                               7043
# Start Time                2019-01-31 22:56:00-05:00
# Start Station Name  Queens Quay W / Lower Simcoe St
# End Station Id                               7324.0
# End Time                  2019-01-31 23:06:00-05:00
# End Station Name    King St W / Charlotte St (West)
# Bike Id                                        1418
# User Type                             Annual Member
#
#                                           2439514                    2439515  \
# Trip Id                                   4653116                    4653117
# Subscription Id                            284151                     174757
# Trip Duration                                 295                        340
# Start Station Id                             7092                       7077
# Start Time              2019-01-31 23:44:00-05:00  2019-01-31 23:45:00-05:00
# Start Station Name            Pape Subway Green P         College Park South
# End Station Id                             7353.0                     7028.0
# End Time                2019-01-31 23:49:00-05:00  2019-01-31 23:51:00-05:00
# End Station Name    Fulton Ave / Pape Ave - SMART       Gould St / Mutual St
# Bike Id                                      2386                        464
# User Type                           Annual Member              Annual Member
#
#                                       2439516  Count
# Trip Id                               4653118      0
# Subscription Id                        247059      0
# Trip Duration                             513      0
# Start Station Id                         7163      0
# Start Time          2019-01-31 23:50:00-05:00      0
# Start Station Name         Yonge St / Wood St      0
# End Station Id                         7333.0  454.0
# End Time            2019-01-31 23:58:00-05:00      0
# End Station Name      King St E / Victoria St    454
# Bike Id                                  2784      0
# User Type                       Annual Member      0
#
# [11 rows x 2439518 columns]

# %% [markdown]
# We can see that some columns have missing values. However, having missing data does not necessarily mean that something is wrong with an entry. For example, the `Weather` column contains the following unique values:

# %%
weather_data['Weather'].unique().tolist()
# Out:
# [nan,
#  'Rain',
#  'Haze',
#  'Thunderstorms,Heavy Rain',
#  'Thunderstorms,Rain',
#  'Fog',
#  'Rain,Fog',
#  'Thunderstorms',
#  'Moderate Rain,Fog',
#  'Thunderstorms,Moderate Rain',
#  'Thunderstorms,Fog',
#  'Moderate Rain',
#  'Thunderstorms,Heavy Rain,Fog',
#  'Heavy Rain,Fog',
#  'Snow',
#  'Freezing Rain,Fog',
#  'Moderate Snow',
#  'Heavy Snow',
#  'Rain,Snow',
#  'Thunderstorms,Moderate Rain,Fog',
#  'Snow,Blowing Snow',
#  'Haze,Blowing Snow',
#  'Freezing Rain']

# %% [markdown]
# You can see that only non-normal/clear weather events are listed. So, when `weather_data['Weather'] == NaN`, the conditions are clear. Therefore, we would never want to remove rows where `weather_data['Weather'] == NaN`.
#
# We can see that the first 8 columns of `weather_data_missing` have no missing data, so we can leave `weather_data` and address the missingness on a case-by-case basis depending on which columns we're analyzing.
#
# For `trips_data`, we can see that `'End Station Id'` and `'End Station Name'` have 454 missing values, which is only 0.01% of the dataset. This might suggest corruption and given the small number of missing values, we can safetly drop these rows.

# %%
trips_data.shape
# Out:
# (2439517, 11)

# %% [markdown]
# ## Question 3b - Missing Data
# Drop any rows of `trips_data` with missing values.

# %%
# Write your code here.
trips_data = trips_data.dropna()

# View DataFrame
trips_data.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0  6426456           471215            711              7207
# 1  6426455           463175            517              7462
# 2  6426453           468059            460              7210
# 3  6426452           468816            229              7251
# 4  6426454           471340            612              7467
#
#                  Start Time                            Start Station Name  \
# 0 2019-09-01 00:00:00-05:00                     Dundas St W / Crawford St
# 1 2019-09-01 00:00:00-05:00                      Richmond St E / Yonge St
# 2 2019-09-01 00:00:00-05:00      Mary McCormick Rec Centre (Sheridan Ave)
# 3 2019-09-01 00:00:00-05:00  The Royal Ontario Museum (Bloor St Entrance)
# 4 2019-09-01 00:00:00-05:00                Lower Simcoe St / Bremner Blvd
#
#    End Station Id                  End Time  \
# 0          7150.0 2019-09-01 00:12:00-05:00
# 1          7385.0 2019-09-01 00:08:00-05:00
# 2          7136.0 2019-09-01 00:07:00-05:00
# 3          7419.0 2019-09-01 00:03:00-05:00
# 4          7016.0 2019-09-01 00:10:00-05:00
#
#                                 End Station Name  Bike Id      User Type
# 0  Dufferin St / Sylvan Av (Dufferin Grove Park)     3331  Casual Member
# 1                                20 Charles St E     1534  Annual Member
# 2                         Queen St W / Close Ave      877  Casual Member
# 3                          Bloor St W / Huron St      640  Casual Member
# 4        Bay St / Queens Quay W (Ferry Terminal)     2722  Casual Member

# %%
trips_data.shape
# Out:
# (2439063, 11)

# %% [markdown]
# ## Question 4a - Outliers
# Outliers in your datasets can be both good and bad. One the one hand, they may contain important information while on the other hand, they skew your visualizations and may bias your models.
#
# As a simple first pass, let's look at the summary statistics for `trips_data` using `.describe()` (remember, it only works for numeric data).

# %%
trips_data.describe()
# Out:
#             Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# count  2.439063e+06     2.439063e+06   2.439063e+06      2.439063e+06
# mean   5.957049e+06     3.529029e+05   1.044105e+03      7.183801e+03
# std    7.885706e+05     8.000075e+04   1.853783e+04      1.355055e+02
# min    4.581278e+06     6.537700e+04   0.000000e+00      7.000000e+03
# 25%    5.277110e+06     3.099960e+05   4.250000e+02      7.058000e+03
# 50%    5.956799e+06     3.394030e+05   6.880000e+02      7.171000e+03
# 75%    6.637216e+06     4.073290e+05   1.081000e+03      7.282000e+03
# max    7.334127e+06     5.239440e+05   1.240378e+07      7.511000e+03
#
#        End Station Id       Bike Id
# count    2.439063e+06  2.439063e+06
# mean     7.183547e+03  2.718808e+03
# std      1.354044e+02  1.388448e+03
# min      7.000000e+03  1.400000e+01
# 25%      7.058000e+03  1.614000e+03
# 50%      7.171000e+03  2.909000e+03
# 75%      7.282000e+03  3.801000e+03
# max      7.511000e+03  5.038000e+03

# %% [markdown]
# Right away we notice something a bit funny with `'Trip Duration'`. The min and max values seem implausible. A trip cannot last `0 seconds` (you'd have to be biking at the speed of light!) and its unlikely that a trip lasted for `1.240378e+07 seconds`. `1.240378e+07 seconds` is roughly 4.78 months, which would be quite the ride and cost tens of thousands of dollars. We can see that the average `'Trip Duration'` is roughly 17 minutes.
#
# We've been told by Bike Share Toronto that trips lasting less than 1 minute can be considered false trips. Remove all trips from `trips_data` with a duration less than 60 seconds.

# %%
# Write your code here
trips_data = trips_data[~(trips_data['Trip Duration']<60)] 

# View DataFrame
trips_data.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0  6426456           471215            711              7207
# 1  6426455           463175            517              7462
# 2  6426453           468059            460              7210
# 3  6426452           468816            229              7251
# 4  6426454           471340            612              7467
#
#                  Start Time                            Start Station Name  \
# 0 2019-09-01 00:00:00-05:00                     Dundas St W / Crawford St
# 1 2019-09-01 00:00:00-05:00                      Richmond St E / Yonge St
# 2 2019-09-01 00:00:00-05:00      Mary McCormick Rec Centre (Sheridan Ave)
# 3 2019-09-01 00:00:00-05:00  The Royal Ontario Museum (Bloor St Entrance)
# 4 2019-09-01 00:00:00-05:00                Lower Simcoe St / Bremner Blvd
#
#    End Station Id                  End Time  \
# 0          7150.0 2019-09-01 00:12:00-05:00
# 1          7385.0 2019-09-01 00:08:00-05:00
# 2          7136.0 2019-09-01 00:07:00-05:00
# 3          7419.0 2019-09-01 00:03:00-05:00
# 4          7016.0 2019-09-01 00:10:00-05:00
#
#                                 End Station Name  Bike Id      User Type
# 0  Dufferin St / Sylvan Av (Dufferin Grove Park)     3331  Casual Member
# 1                                20 Charles St E     1534  Annual Member
# 2                         Queen St W / Close Ave      877  Casual Member
# 3                          Bloor St W / Huron St      640  Casual Member
# 4        Bay St / Queens Quay W (Ferry Terminal)     2722  Casual Member

# %%
trips_data.shape
# Out:
# (2422124, 11)

# %% [markdown]
# ## Question 4b - Outliers
# Next, remove any `'Trip Duration'` values less than `Q1 - 1.5 * IQR` and greater than `Q3 + 1.5 * IQR`.
#
# - Q1: The first quartile (`.quantile(0.25)`)
# - Q3: The third quartile (`.quantile(0.75)`)
# - IQR: The first quartil (`Q3 - Q1`)
# <br>
# <img src="images/probability_density.png" alt="drawing" width="450"/>
# <br>

# %%
# Write your code here
q_1 = trips_data['Trip Duration'].quantile(0.25)
q_3 = trips_data['Trip Duration'].quantile(0.75)
iqr = (q_3 - q_1)
filter_1 = (q_1 - (1.5*(iqr)))
filter_2 = (q_3 + (1.5*(iqr)))

trips_data = trips_data[(trips_data['Trip Duration']>= filter_1) & (trips_data['Trip Duration']<= filter_2)]

# View DataFrame
trips_data.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0  6426456           471215            711              7207
# 1  6426455           463175            517              7462
# 2  6426453           468059            460              7210
# 3  6426452           468816            229              7251
# 4  6426454           471340            612              7467
#
#                  Start Time                            Start Station Name  \
# 0 2019-09-01 00:00:00-05:00                     Dundas St W / Crawford St
# 1 2019-09-01 00:00:00-05:00                      Richmond St E / Yonge St
# 2 2019-09-01 00:00:00-05:00      Mary McCormick Rec Centre (Sheridan Ave)
# 3 2019-09-01 00:00:00-05:00  The Royal Ontario Museum (Bloor St Entrance)
# 4 2019-09-01 00:00:00-05:00                Lower Simcoe St / Bremner Blvd
#
#    End Station Id                  End Time  \
# 0          7150.0 2019-09-01 00:12:00-05:00
# 1          7385.0 2019-09-01 00:08:00-05:00
# 2          7136.0 2019-09-01 00:07:00-05:00
# 3          7419.0 2019-09-01 00:03:00-05:00
# 4          7016.0 2019-09-01 00:10:00-05:00
#
#                                 End Station Name  Bike Id      User Type
# 0  Dufferin St / Sylvan Av (Dufferin Grove Park)     3331  Casual Member
# 1                                20 Charles St E     1534  Annual Member
# 2                         Queen St W / Close Ave      877  Casual Member
# 3                          Bloor St W / Huron St      640  Casual Member
# 4        Bay St / Queens Quay W (Ferry Terminal)     2722  Casual Member

# %%
trips_data.shape
# Out:
# (2328803, 11)

# %% [markdown]
# ## Question 4c - Outliers
# Plot a histogram + density plot using `sns.distplot()` of the `'Trip Duration'`. Ensure that `'Trip Duration'` is displayed in minutes. Your plot should look something like this.
# <br>
# <img src="images/trip_durations.png" alt="drawing" width="450"/>
# <br>

# %%
# Write your code here.
plt.figure(figsize=(10,5))
plt.title('Distribution of trip durations',fontsize=15)
df=trips_data
graph = sns.distplot(x = df['Trip Duration']/60)
graph.xaxis.set_tick_params(labelsize=10)
graph.yaxis.set_tick_params(labelsize=10)
graph.set_xlabel('Trip Duration, minutes', fontsize=15)
graph.set_ylabel('Probability Density', fontsize=15)
plt.show()

# %% [markdown]
# ## Question 5 - Duplicates
# Remove any entries from `trips_data` which have the same `'Trip Id'`.

# %%
# Write your code here
trips_data.drop_duplicates(['Trip Id'])

# View DataFrame
trips_data.head()
# Out:
#    Trip Id  Subscription Id  Trip Duration  Start Station Id  \
# 0  6426456           471215            711              7207
# 1  6426455           463175            517              7462
# 2  6426453           468059            460              7210
# 3  6426452           468816            229              7251
# 4  6426454           471340            612              7467
#
#                  Start Time                            Start Station Name  \
# 0 2019-09-01 00:00:00-05:00                     Dundas St W / Crawford St
# 1 2019-09-01 00:00:00-05:00                      Richmond St E / Yonge St
# 2 2019-09-01 00:00:00-05:00      Mary McCormick Rec Centre (Sheridan Ave)
# 3 2019-09-01 00:00:00-05:00  The Royal Ontario Museum (Bloor St Entrance)
# 4 2019-09-01 00:00:00-05:00                Lower Simcoe St / Bremner Blvd
#
#    End Station Id                  End Time  \
# 0          7150.0 2019-09-01 00:12:00-05:00
# 1          7385.0 2019-09-01 00:08:00-05:00
# 2          7136.0 2019-09-01 00:07:00-05:00
# 3          7419.0 2019-09-01 00:03:00-05:00
# 4          7016.0 2019-09-01 00:10:00-05:00
#
#                                 End Station Name  Bike Id      User Type
# 0  Dufferin St / Sylvan Av (Dufferin Grove Park)     3331  Casual Member
# 1                                20 Charles St E     1534  Annual Member
# 2                         Queen St W / Close Ave      877  Casual Member
# 3                          Bloor St W / Huron St      640  Casual Member
# 4        Bay St / Queens Quay W (Ferry Terminal)     2722  Casual Member

# %% [markdown]
# # 4. Merge Datasets
# To facilitate an analysis of the effect of weather on ridership, we must merge two DataFrames (`weather_data` and `trips_data`).
#
# ## Question 6
# Use the `.merge()` function to combine `weather_data` and `trips_data` using datetime information and set the output to a new variable called `data_merged`. In `trips_data` there are two time stamps corresponding to the start and end of the ride. Use the `'Start Time'` of the rides to merge.
#
# `trips_data` datetimes contain information down to the minute, while `weather_data` is reported every hour. Thus, we must merge based on a common year, month, day, hour. Hint: create a new column in `trips_data` called `'merge_time'` and set it equal to `trips_data['Start Time']` rounded to the nearest hour.

# %%
# Write your code here
trips_data['merge_time']=trips_data['Start Time'].dt.round(freq='H')
data_merged = pd.merge(weather_data,trips_data,left_on='Date/Time',right_on='merge_time')

# View DataFrame
data_merged.head()
# Out:
#    ï»¿"Longitude (x)"  Latitude (y)         Station Name  Climate ID  Year  \
# 0               -79.4         43.63  TORONTO CITY CENTRE     6158359  2019
# 1               -79.4         43.63  TORONTO CITY CENTRE     6158359  2019
# 2               -79.4         43.63  TORONTO CITY CENTRE     6158359  2019
# 3               -79.4         43.63  TORONTO CITY CENTRE     6158359  2019
# 4               -79.4         43.63  TORONTO CITY CENTRE     6158359  2019
#
#    Month  Day   Time  Temp (Â°C) Temp Flag  ...  Trip Duration  \
# 0     12    1  00:00        -0.2       NaN  ...            440
# 1     12    1  00:00        -0.2       NaN  ...           1060
# 2     12    1  00:00        -0.2       NaN  ...            296
# 3     12    1  00:00        -0.2       NaN  ...            587
# 4     12    1  00:00        -0.2       NaN  ...           1025
#
#   Start Station Id                Start Time  \
# 0             7055 2019-12-01 00:02:00-05:00
# 1             7403 2019-12-01 00:05:00-05:00
# 2             7123 2019-12-01 00:05:00-05:00
# 3             7015 2019-12-01 00:05:00-05:00
# 4             7384 2019-12-01 00:05:00-05:00
#
#                         Start Station Name  End Station Id  \
# 0                   Jarvis St / Carlton St          7100.0
# 1  Lascelles Blvd / Eglinton Ave W - SMART          7128.0
# 2              424 Wellington St W - SMART          7211.0
# 3           King St W / Bay St (West Side)          7000.0
# 4            Cumberland Ave / Bay St SMART          7120.0
#
#                    End Time                End Station Name Bike Id  \
# 0 2019-12-01 00:10:00-05:00  Dundas St E / Regent Park Blvd    3556
# 1 2019-12-01 00:22:00-05:00           Yonge St / Aylmer Ave    4518
# 2 2019-12-01 00:10:00-05:00    Fort York Blvd / Garrison Rd    1837
# 3 2019-12-01 00:15:00-05:00    Fort York  Blvd / Capreol Ct     237
# 4 2019-12-01 00:22:00-05:00         Gerrard St E / River St    4748
#
#        User Type                merge_time
# 0  Annual Member 2019-12-01 00:00:00-05:00
# 1  Annual Member 2019-12-01 00:00:00-05:00
# 2  Annual Member 2019-12-01 00:00:00-05:00
# 3  Annual Member 2019-12-01 00:00:00-05:00
# 4  Annual Member 2019-12-01 00:00:00-05:00
#
# [5 rows x 39 columns]

# %% [markdown]
# # 5. Analysis of 'User Type'
# ## Question 7a
# First, we'll explore the daily number for Annual Members and Casual Members. Casual Members pay on a per ride basis while Annual Members pay a monthly subcription fee. The DataFrame `data_merged` has a temporal resolution of a minute. Therefore, in order to look at daily numbers, we'll need to convert `data_merged` so that every row corresponds to a day. Create a new DataFrame called `data_days` with three columns:
# - ride: The total number of rides for a particular day.
# - annual_members: Number of rides by Annual Members.
# - casual_members: Number of rides by Casual Members.
# - workday: Was this day a workday (True) or a weekend day (False).
#
# Your DataFrame should looks something like this.
#
# <br>
# <img src="images/data_days.png" alt="drawing" width="500"/>
# <br>
#
# As a quick sanity check you can check that the number of rows in `data_merged` is equal to the sum of `data_days['rides']`.
#
# Hint: You can use the `.groupby()` method and the `agg()` method to compute this transformation in a single line of code.

# %%
data_merged.set_index('Start Time').resample('D').count()#.groupby(["Start Time","User Type"]).count()
# Out:
#                            ï»¿"Longitude (x)"  Latitude (y)  Station Name  \
# Start Time
# 2019-01-01 00:00:00-05:00                 992           992           992
# 2019-01-02 00:00:00-05:00                2214          2214          2214
# 2019-01-03 00:00:00-05:00                2220          2220          2220
# 2019-01-04 00:00:00-05:00                3225          3225          3225
# 2019-01-05 00:00:00-05:00                2089          2089          2089
# ...                                       ...           ...           ...
# 2019-12-27 00:00:00-05:00                2513          2513          2513
# 2019-12-28 00:00:00-05:00                2414          2414          2414
# 2019-12-29 00:00:00-05:00                1007          1007          1007
# 2019-12-30 00:00:00-05:00                2441          2441          2441
# 2019-12-31 00:00:00-05:00                1909          1909          1909
#
#                            Climate ID  Year  Month   Day  Time  Temp (Â°C)  \
# Start Time
# 2019-01-01 00:00:00-05:00         992   992    992   992   992         992
# 2019-01-02 00:00:00-05:00        2214  2214   2214  2214  2214        2214
# 2019-01-03 00:00:00-05:00        2220  2220   2220  2220  2220        2220
# 2019-01-04 00:00:00-05:00        3225  3225   3225  3225  3225        3225
# 2019-01-05 00:00:00-05:00        2089  2089   2089  2089  2089        2089
# ...                               ...   ...    ...   ...   ...         ...
# 2019-12-27 00:00:00-05:00        2513  2513   2513  2513  2513        2513
# 2019-12-28 00:00:00-05:00        2414  2414   2414  2414  2414        2414
# 2019-12-29 00:00:00-05:00        1007  1007   1007  1007  1007        1007
# 2019-12-30 00:00:00-05:00        2441  2441   2441  2441  2441        2441
# 2019-12-31 00:00:00-05:00        1909  1909   1909  1909  1909        1909
#
#                            Temp Flag  ...  Subscription Id  Trip Duration  \
# Start Time                            ...
# 2019-01-01 00:00:00-05:00          0  ...              992            992
# 2019-01-02 00:00:00-05:00          0  ...             2214           2214
# 2019-01-03 00:00:00-05:00          0  ...             2220           2220
# 2019-01-04 00:00:00-05:00          0  ...             3225           3225
# 2019-01-05 00:00:00-05:00          0  ...             2089           2089
# ...                              ...  ...              ...            ...
# 2019-12-27 00:00:00-05:00          0  ...             2513           2513
# 2019-12-28 00:00:00-05:00          0  ...             2414           2414
# 2019-12-29 00:00:00-05:00          0  ...             1007           1007
# 2019-12-30 00:00:00-05:00          0  ...             2441           2441
# 2019-12-31 00:00:00-05:00          0  ...             1909           1909
#
#                            Start Station Id  Start Station Name  \
# Start Time
# 2019-01-01 00:00:00-05:00               992                 992
# 2019-01-02 00:00:00-05:00              2214                2214
# 2019-01-03 00:00:00-05:00              2220                2220
# 2019-01-04 00:00:00-05:00              3225                3225
# 2019-01-05 00:00:00-05:00              2089                2089
# ...                                     ...                 ...
# 2019-12-27 00:00:00-05:00              2513                2513
# 2019-12-28 00:00:00-05:00              2414                2414
# 2019-12-29 00:00:00-05:00              1007                1007
# 2019-12-30 00:00:00-05:00              2441                2441
# 2019-12-31 00:00:00-05:00              1909                1909
#
#                            End Station Id  End Time  End Station Name  \
# Start Time
# 2019-01-01 00:00:00-05:00             992       992               992
# 2019-01-02 00:00:00-05:00            2214      2214              2214
# 2019-01-03 00:00:00-05:00            2220      2220              2220
# 2019-01-04 00:00:00-05:00            3225      3225              3225
# 2019-01-05 00:00:00-05:00            2089      2089              2089
# ...                                   ...       ...               ...
# 2019-12-27 00:00:00-05:00            2513      2513              2513
# 2019-12-28 00:00:00-05:00            2414      2414              2414
# 2019-12-29 00:00:00-05:00            1007      1007              1007
# 2019-12-30 00:00:00-05:00            2441      2441              2441
# 2019-12-31 00:00:00-05:00            1909      1909              1909
#
#                            Bike Id  User Type  merge_time
# Start Time
# 2019-01-01 00:00:00-05:00      992        992         992
# 2019-01-02 00:00:00-05:00     2214       2214        2214
# 2019-01-03 00:00:00-05:00     2220       2220        2220
# 2019-01-04 00:00:00-05:00     3225       3225        3225
# 2019-01-05 00:00:00-05:00     2089       2089        2089
# ...                            ...        ...         ...
# 2019-12-27 00:00:00-05:00     2513       2513        2513
# 2019-12-28 00:00:00-05:00     2414       2414        2414
# 2019-12-29 00:00:00-05:00     1007       1007        1007
# 2019-12-30 00:00:00-05:00     2441       2441        2441
# 2019-12-31 00:00:00-05:00     1909       1909        1909
#
# [365 rows x 38 columns]

# %%
# Write your code here
data_days = data_merged.set_index('Start Time').resample('D').count()['Bike Id'].to_frame().rename(columns={'Bike Id':'rides'})

# View DataFrame
data_days.head()
# Out:
#                            rides
# Start Time
# 2019-01-01 00:00:00-05:00    992
# 2019-01-02 00:00:00-05:00   2214
# 2019-01-03 00:00:00-05:00   2220
# 2019-01-04 00:00:00-05:00   3225
# 2019-01-05 00:00:00-05:00   2089

# %% [markdown]
# ## Question 7b
# Use `sns.distplot()` to create a plot showing the distributions of daily ride counts from `data_days` for Casual Members and Annual Members. Your plot should look something like this.
#
# <br>
# <img src="images/ride_count_histogram.png" alt="drawing" width="600"/>
# <br>

# %%
# Write your code here.
...

# %% [markdown]
# ## Question 7c
# Use `sns.scatterplot()` to create a scatter plot showing the relationship between daily ride counts from `data_days` for Casual Members and Annual Members. Your plot should look something like this.
#
# <br>
# <img src="images/ride_count_scatter.png" alt="drawing" width="600"/>
# <br>

# %%
# Write your code here.
...

# %% [markdown]
# ## Question 7d
# Looking at the figure you've generated for **Question 7c**, some interesting outliers have appeared. In particular, there are some `workday` data points that appear to follow the `non-workday` trend. What could explain these outlier and what additional information could be collect to address them?

# %% [markdown]
# *Type your answer here, replacing this text.*

# %% [markdown]
# ## Question 7e
# Let's examine the hourly ride counts for `Annual Members` and `Casual Members`. First thing we have to do i create a new DataFrame called `data_hours`. `data_hours` should have its index set to hours (0 to 23) using the `'Start Time'` column and three columns `'rides', 'annual_members', 'casual_members'`. These should be average hourly values.

# %%
# Write your code here.
data_hours = ...

# View DataFrame
data_hours.head()

# %% [markdown]
# ## Question 7f
# Use `data_hours` to create a plot showing the average number of hourly rides for `Annual Members` and `Casual Memebers`. Your plot should look something like this.
#
# <br>
# <img src="images/hourly_rides.png" alt="drawing" width="600"/>
# <br>

# %%
# Write your code here.
...

# %% [markdown]
# ## Question 7g
# What can you observe from the plot? Hypothesize about the meaning of the peaks for casual and annual membership riders.

# %% [markdown]
# *Type your answer here, replacing this text.*

# %% [markdown]
# # 5. Analysis of 'Weather'
# In this section, we'll be looking at the influence of weather conditions, such as temperature and precipitation, on ridership activity.
#
# First, let's take a look at the missingness for `data_merged`.

# %%
data_merged.isnull().sum(axis=0).to_frame('count')

# %% [markdown]
# We can see that the `'Weather'` column has 824,894 missing values. Now let's take a look at the unique labels in the `'Weather'` column and how many entries contain each one.

# %%
data_merged.groupby('Weather')['Trip Id'].count().sort_values(ascending=False)

# %% [markdown]
# We can see that the most common `'Weather'` labels are `'Rain'`, `'Fog'`, and `'Rain,Fog'`. There is no label for **clear** condition, which suggests that the 824,894 NaN values correspond to **clear** conditions.
#
# ## Question 8a
# The first thing we have to do is transform `data_merged` to contain aggregated values for each hour. Remember, `data_merged`'s grannularity is at the ride level. Each row, corresponds to one ride with a temporal resolution of one minute. Therefore, there can be multiple entries for the same minute.
#
# Create a new variable called `hourly_rides_and_weather` and assign a DataFrame to it containing the following information:
# - Index: DatetimeIndex with a resolution of 1 hour (2019-01-01 10:00:00, 2019-01-01 11:00:00, 2019-01-01 12:00:00, 2019-01-01 13:00:00, etc.). Use `'Start Time'` to generate this index.
# - Column 1 `'rides'`: How many rides were recorded during a particular hour.
# - Column 2 `'annual_members'`: How many `'Annual Member'` rides were recorded during a particular hour.
# - Column 3 `'casual_members'`: How many `'Casual Member'` rides were recorded during a particular hour.
# - Column 4 `'workday'`: Does this hour correspond to a workday or a weekend day (True, False).
# - Column 5 `'temp'`: Reported temperature from the `'Temp (°C)'` column.
# - Column 6 `'weather'`: Reported weather conditions from the `'Weather'` column.
#
# <br>
# <img src="images/hourly_rides_and_weather_1.png" alt="drawing" width="600"/>
# <br>
#
# Hints:
# 1. Use `.groupby()` and `.agg()`.
# 2. This is an example of how you can use `.agg()` to compute Column 1 `'rides'`: `.agg(rides=('rides', 'sum'))`.
# 3. Use `data_merged['Start Time'].dt.floor('H')` to groupby hour.

# %%
# Write your code here
hourly_rides_and_weather = ...

# View DataFrame
hourly_rides_and_weather.head(10)

# %% [markdown]
# ## Question 8b
# Next, let's transform `hourly_rides_and_weather` from hourly to daily sampling. As we saw for **Question 7g**, there are strong trends within each day, which could complicate our initial analysis. Therefore, by aggrigating by day-of-the-week, we'll remove some of this trend.
#
# Modify `hourly_rides_and_weather` to include the following information:
# - Index: DatetimeIndex with a resolution of 1 day (2019-01-01 00:00:00, 2019-01-02 00:00:00, 2019-01-03 00:00:00, 2019-01-04 00:00:00, etc.). Use `'Start Time'` to generate this index.
# - Column 1 `'rides'`: How many rides were recorded during a particular day.
# - Column 2 `'annual_members'`: How many `'Annual Member'` rides were recorded during a particular day.
# - Column 3 `'casual_members'`: How many `'Casual Member'` rides were recorded during a particular day.
# - Column 4 `'workday'`: Does this a workday or a weekend day (True, False).
# - Column 5 `'temp'`: The maximum temperature recorded for a particular day.
# - Column 6 `'weather'`: This column should contain one of two values (`'clear'` or `'Precipitation'`). `'Clear'` should be assigned to days where 50% or more of the hours of that day had no precipitation events (Rain, Fog, Snow, Rain, Fog, etc.). Remember, `hourly_rides_and_weather['weather']` contains an `NaN` value when there was no precipitation event. When more than 50% of the hours of a day had a precipitation event, assign `'Precipitation'`.
#
# <br>
# <img src="images/hourly_rides_and_weather_2.png" alt="drawing" width="600"/>
# <br>

# %%
# Write your code here
hourly_rides_and_weather = ...

# View DataFrame
hourly_rides_and_weather.head(10)

# %% [markdown]
# ## Question 8c
# Let's investigate the relationship between weather conditions and ridership numbers. Create a violin plot using `sns.violinplot()` that looks something like the figure below.
#
# <br>
# <img src="images/weather_daily_rides_1.png" alt="drawing" width="600"/>
# <br>

# %%
# Write your code here
...

# %% [markdown]
# ## Question 8d
# Let's investigate the relationship between the maximum daily temperature and ridership numbers. Create a scatter plot using `sns.scatterplot()` that looks something like the figure below.
#
# <br>
# <img src="images/temp_daily_rides.png" alt="drawing" width="600"/>
# <br>

# %%
# Write your code here
...

# %% [markdown]
# ## Question 8e
# Reflect on the figures you've generated for **Question 8c** and **Question 8d**. What trends can you identify from these plots and can you suggest any potential issues with them or modifications you'd suggest to improve them?

# %% [markdown]
# *Type your answer here, replacing this text.*

# %% [markdown]
# **Congratulation, you're done Assignment 4. Review your answers and clean up that code before submitting on Quercus. `#cleancode`**
